# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik-tee/Machine-Learning-Practice/blob/main/simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np;
import pandas as pd;
from google.colab import files
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
uploaded= files.upload()
df=pd.read_csv("height-weight.csv")
df.head()
# Out:
#      <input type="file" id="files-a1799257-580f-49ae-a5fc-fcd6b923df92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1799257-580f-49ae-a5fc-fcd6b923df92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.scatter(df['Weight'],df['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
plt.title('Height vs Weight')
# Out:
# Text(0.5, 1.0, 'Height vs Weight')

# %%
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %%
X=df[["Weight"]]

# %%
y=df["Height"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import standardScaler

# %%
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)

# %%
X_test_scaled=scaler.transform(X_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X_test
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train_scaled,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("Coefficient or slope",regression.coef_)
print("Intercept",regression.intercept_)
# Out:
# Coefficient or slope [1.04792503]
# Intercept 80.52684512622542

# %%
plt.scatter(X_train_scaled,y_train)
plt.plot(X_train_scaled,regression.predict(X_train_scaled))

# %%
y_pred=regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 114.84069295228699
# 9.66512588679501
# 10.716374991212605

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7360826717981276

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6701033397476595

# %%
## OLS Linear Regression
import statsmodels.api as sm

# %%
model=sm.OLS(y_train,X_train).fit()

# %%
prediction=model.predict(X_test)
print(prediction)
# Out:
# [ 0.70487577  0.70487577 -3.5018828   2.87199382 -0.95233215  4.14676914]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Height   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.985
# Method:                 Least Squares   F-statistic:                              1133.
# Date:                Thu, 18 Jun 2026   Prob (F-statistic):                    2.80e-16
# Time:                        05:53:43   Log-Likelihood:                         -73.806
# No. Observations:                  17   AIC:                                      149.6
# Df Residuals:                      16   BIC:                                      150.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
regression.predict(scaler.transform([[72]]))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([155.97744705])
